# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
np.mean([1,2,3,4,5,6])
# Out:
# 3.5

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd #as - aliance

# %%
d = {'A': [1,2,3,4,5] ,
     'B' : [100,200,300,400,500]}

# %%
pd.DataFrame(d)
# Out:
#    A    B
# 0  1  100
# 1  2  200
# 2  3  300
# 3  4  400
# 4  5  500

# %%
pd.read_csv('addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
pd.read_csv('addresses.csv',index_col=[1,2,3,4,5])
# Out:
#                                                                                      id  \
# location_id address_1                  address_2 city                state_province
# 1           2600 Middlefield Road      NaN       Redwood City        CA               1
# 2           24 Second Avenue           NaN       San Mateo           CA               2
# 3           24 Second Avenue           NaN       San Mateo           CA               3
# 4           24 Second Avenue           NaN       San Mateo           CA               4
# 5           24 Second Avenue           NaN       San Mateo           CA               5
# 6           800 Middle Avenue          NaN       Menlo Park          CA               6
# 7           500 Arbor Road             NaN       Menlo Park          CA               7
# 8           800 Middle Avenue          NaN       Menlo Park          CA               8
# 9           2510 Middlefield Road      NaN       Redwood City        CA               9
# ...

# %%
data = pd.read_csv('addresses.csv',names=['A','B','C','D','E'])

# %%
data.head()
# Out:
#                                               A             B               C  \
# id location_id address_1              address_2          city  state_province
# 1  1           2600 Middlefield Road        NaN  Redwood City              CA
# 2  2           24 Second Avenue             NaN     San Mateo              CA
# 3  3           24 Second Avenue             NaN     San Mateo              CA
# 4  4           24 Second Avenue             NaN     San Mateo              CA
#
#                                                 D        E
# id location_id address_1              postal_code  country
# 1  1           2600 Middlefield Road        94063       US
# 2  2           24 Second Avenue             94401       US
# 3  3           24 Second Avenue             94403       US
# 4  4           24 Second Avenue             94401       US

# %%
data.sample()
# Out:
#                          A           B   C           D   E
# 8 8 800 Middle Avenue  NaN  Menlo Park  CA  94025-9881  US

# %%
data.head()
# Out:
#                                               A             B               C  \
# id location_id address_1              address_2          city  state_province
# 1  1           2600 Middlefield Road        NaN  Redwood City              CA
# 2  2           24 Second Avenue             NaN     San Mateo              CA
# 3  3           24 Second Avenue             NaN     San Mateo              CA
# 4  4           24 Second Avenue             NaN     San Mateo              CA
#
#                                                 D        E
# id location_id address_1              postal_code  country
# 1  1           2600 Middlefield Road        94063       US
# 2  2           24 Second Avenue             94401       US
# 3  3           24 Second Avenue             94403       US
# 4  4           24 Second Avenue             94401       US

# %%
data.sample(5)
# Out:
#                               A              B   C           D   E
# 15 15 1500 Valencia Street  NaN  San Francisco  CA       94110  US
# 16 16 1161 South Bernardo   NaN      Sunnyvale  CA       94087  US
# 8  8  800 Middle Avenue     NaN     Menlo Park  CA  94025-9881  US
# 6  6  800 Middle Avenue     NaN     Menlo Park  CA  94025-9881  US
# 2  2  24 Second Avenue      NaN      San Mateo  CA       94401  US
