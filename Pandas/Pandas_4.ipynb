# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Fare"] > 200]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
# travelling with 0 fare
len(df[df["Fare"] <= 0])
# Out:
# 15

# %%
len(df[df["Fare"] <= 10])
# Out:
# 336

# %%
# fare between 1-10 --> 321
len(df[(df["Fare"] > 0) & (df["Fare"] <= 10)])
# Out:
# 321

# %%
# fare between 1-10 --> 321
len(df[(df["Fare"] > 10) & (df["Fare"] <= 20)])
# Out:
# 179

# %%
# fare between 1-10 --> 321
len(df[(df["Fare"] > 30) & (df["Fare"] <= 40)])
# Out:
# 58

# %%
# fare between 1-10 --> 321
len(df[(df["Fare"] > 50) & (df["Fare"] <= 60)])
# Out:
# 38

# %%
# fare between 1-10 --> 321
len(df[(df["Fare"] > 70) & (df["Fare"] <= 80)])
# Out:
# 31

# %%
# fare between 1-10 --> 321
len(df[(df["Fare"] > 90) & (df["Fare"] <= 100)])
# Out:
# 4

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# creating new column

# %%
df["my_Price"] =  100 + df["Fare"]

# %%
df["my_Price"]
# Out:
# 0      107.2500
# 1      171.2833
# 2      107.9250
# 3      153.1000
# 4      108.0500
#          ...
# 886    113.0000
# 887    130.0000
# 888    123.4500
# 889    130.0000
# 890    107.7500
# Name: my_Price, Length: 891, dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  my_Price
# 0      0         A/5 21171   7.2500   NaN        S  107.2500
# 1      0          PC 17599  71.2833   C85        C  171.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S  107.9250
# 3      0            113803  53.1000  C123        S  153.1000
# ...

# %%
df["Age_new"] = df["Pclass"] + df["Age"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  my_Price  Age_new
# 0      0         A/5 21171   7.2500   NaN        S  107.2500     25.0
# 1      0          PC 17599  71.2833   C85        C  171.2833     39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  107.9250     29.0
# ...

# %%
df["Age_new"] = 100

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  my_Price  Age_new
# 0      0         A/5 21171   7.2500   NaN        S  107.2500      100
# 1      0          PC 17599  71.2833   C85        C  171.2833      100
# 2      0  STON/O2. 3101282   7.9250   NaN        S  107.9250      100
# ...

# %%
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df["Fare"] = df["Age"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket  Fare Cabin Embarked  my_Price  Age_new
# 0      0         A/5 21171  22.0   NaN        S  107.2500      100
# 1      0          PC 17599  38.0   C85        C  171.2833      100
# 2      0  STON/O2. 3101282  26.0   NaN        S  107.9250      100
# ...

# %%
# df['new_col'] = new_col
